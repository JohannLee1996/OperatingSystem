# %%
import sys
f1 = open('test.19.gold')
f2 = open('test.19.out')
while 1:
    f1l = f1.readline()
    f2l = f2.readline()
    if f1l!=f2l:
        print(f1l, f2l)
# Out:
# [02:32] AT 875 from YOW to YYZ, departed 01:15, delay 1.
#  [02:32] CP 601 from YYC to YVR, departed 00:49, delay 0.
#
# [02:32] CP 601 from YYC to YVR, departed 00:49, delay 0.
#  [02:32] AT 875 from YOW to YYZ, departed 01:15, delay 1.
#
# [03:02] AT 478 from YHZ to YUL, departed 01:07, delay 0.
#  [03:02] WJ 680 from YZF to YQB, departed 01:46, delay 0.
#
# [03:02] WJ 680 from YZF to YQB, departed 01:46, delay 0.
#  [03:02] AT 478 from YHZ to YUL, departed 01:07, delay 0.
#
# [03:20] AT 846 from YYJ to YXE, departed 01:07, delay 0.
#  [03:20] WJ 771 from YUL to YOW, departed 02:21, delay 2.
#
# [03:20] WJ 771 from YUL to YOW, departed 02:21, delay 2.
#  [03:20] AT 846 from YYJ to YXE, departed 01:07, delay 0.
#
# [03:34] CP 261 from YOW to YWG, departed 00:49, delay 0.
#  [03:34] CP 415 from YQT to YQB, departed 01:13, delay 0.
#
# [03:34] CP 415 from YQT to YQB, departed 01:13, delay 0.
#  [03:34] CP 261 from YOW to YWG, departed 00:49, delay 0.
#
# ...
